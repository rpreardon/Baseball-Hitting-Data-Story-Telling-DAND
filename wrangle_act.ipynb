# %% [markdown]
# # Baseball Data Hitting Statistics
# by Ryan Reardon

# %% [markdown]
# This analysis is based on baseball data of hitting statistics of individual players over a portion of its history  It's clean and limited to only two hitting categories; batting average and homeruns, but it does height, weight and batting stance.  The data set is tidy and without quality issues.

# %% [markdown]
# ## Gather

# %%
#import libraries
import pandas as pd
import numpy as np

# %%
#read in baseball data file
df_data = pd.read_csv('baseball_data.csv')

# %% [markdown]
# ## Assess

# %%
#assess baseball data file
df_data
# Out:
#                    name handedness  height  weight    avg   HR
# 0             Tom Brown          R      73     170  0.000    0
# 1        Denny Lemaster          R      73     182  0.130    4
# 2             Joe Nolan          L      71     175  0.263   27
# 3           Denny Doyle          L      69     175  0.250   16
# 4         Jose Cardenal          R      70     150  0.275  138
# 5             Mike Ryan          R      74     205  0.193   28
# 6        Fritz Peterson          B      72     185  0.159    2
# 7          Dick Bertell          R      72     200  0.250   10
# 8            Rod Kanehl          R      73     180  0.241    6
# 9          Ozzie Osborn          R      74     195  0.000    0
# 10          John LaRose          L      73     185  0.000    0
# 11            Jeff Byrd          R      75     195  0.000    0
# 12         Juan Bonilla          R      69     170  0.256    7
# 13       Frank Tepedino          L      71     185  0.241    6
# 14        Jerry Kutzler          L      73     175  0.000    0
# 15            Rick Wise          R      73     180  0.195   15
# 16        Darrell Evans          L      74     200  0.248  414
# 17        Buck Martinez          R      70     190  0.225   58
# 18      John Wockenfuss          R      72     190  0.262   86
# 19         Tommy McCraw          L      72     183  0.246   75
# 20         Jeff Barkley          B      75     185  0.000    0
# 21         Eric Wilkins          R      73     190  0.000    0
# 22          Britt Burns          L      77     215  0.000    0
# 23             Lee Lacy          R      73     175  0.286   91
# 24            Pete Rose          B      71     192  0.303  160
# 25         Danny Walton          R      72     195  0.223   28
# 26            Bobby Cox          R      71     180  0.225    9
# 27         Brad Wellman          R      72     170  0.231    6
# 28          Jeff Newman          R      74     215  0.224   63
# 29       Pedro Gonzalez          R      72     176  0.244    8
# ...                 ...        ...     ...     ...    ...  ...
# 1127       Dave Johnson          R      73     183  0.000    0
# 1128       Gail Hopkins          L      70     198  0.266   25
# 1129        Doug Frobel          L      76     196  0.201   20
# 1130      Luis Melendez          R      72     165  0.248    9
# 1131    Jerry Augustine          L      72     183  0.000    0
# 1132       Bill Plummer          R      73     190  0.188   14
# 1133       Buck Rodgers          B      74     190  0.232   31
# 1134        Phil Niekro          R      73     180  0.169    7
# 1135         Jeff Holly          L      77     210  0.000    0
# 1136       Tom Poquette          L      70     175  0.268   10
# 1137        Eric Hetzel          R      75     175  0.000    0
# 1138   Brian Asselstine          L      73     175  0.254   12
# 1139        Rick Miller          L      72     175  0.269   28
# 1140         Ed Charles          R      70     170  0.263   86
# 1141         Luis Gomez          R      69     150  0.210    0
# 1142     Dave Lemanczyk          R      76     235  0.000    0
# 1143           Al Jones          R      76     210  0.000    0
# 1144      Floyd Rayford          R      70     190  0.244   38
# 1145          Sam Hinds          R      78     215  0.000    0
# 1146    Tony Conigliaro          R      75     185  0.264  166
# 1147  Clay Christiansen          R      77     205  0.000    0
# 1148           Jim Barr          R      75     205  0.162    1
# 1149         Jerry Remy          L      69     165  0.275    7
# 1150   Larry Rothschild          L      74     180  0.000    0
# 1151        Frank Duffy          R      73     180  0.232   26
# 1152         Gary Lance          B      75     195  0.000    0
# 1153       Tom O'Malley          L      72     180  0.256   13
# 1154        Phil Garner          R      70     175  0.260  109
# 1155     Larry Pashnick          R      75     205  0.000    0
# 1156       Todd Fischer          R      70     170  0.000    0
#
# [1157 rows x 6 columns]

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1157 entries, 0 to 1156
# Data columns (total 6 columns):
# name          1157 non-null object
# handedness    1157 non-null object
# height        1157 non-null int64
# weight        1157 non-null int64
# avg           1157 non-null float64
# HR            1157 non-null int64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 54.3+ KB

# %% [markdown]
# ## Clean
#
# ##### Quality
# - none
# - no quality issues other than including players without batting statistics (AL pitchers) after the DH rule; I left the pitchers with batting stats
#
# ####  Tidy
# - none
# - add column for BMI statistic and BMI Classification for analysis
# - rename and reorder file for analysis

# %% [markdown]
# ### Add BMI Statistic Column

# %%
#add a BMI column
wt = df_data['weight']
ht = df_data['height']

df_data['BMI'] = (wt/ht/ht)*703

#TEST
df_data.head()
# Out:
#              name handedness  height  weight    avg   HR        BMI
# 0       Tom Brown          R      73     170  0.000    0  22.426346
# 1  Denny Lemaster          R      73     182  0.130    4  24.009383
# 2       Joe Nolan          L      71     175  0.263   27  24.404880
# 3     Denny Doyle          L      69     175  0.250   16  25.840160
# 4   Jose Cardenal          R      70     150  0.275  138  21.520408

# %% [markdown]
# ### Add BMI Classification Column

# %%
#function to place BMI into a category
def b(row):
    if row['BMI'] > 40:
        val = 'morbidly obese'
    elif row['BMI'] >= 30 and row['BMI'] <= 39.99999:
        val = 'obese'
    elif row['BMI'] >= 25 and row['BMI'] <= 29.99999:
        val = 'overweight'
    elif row['BMI'] >= 18.5 and row['BMI'] <= 24.99999:
        val = 'normal'
    else:
        val = 'underweight'
    return val

# %%
#name BMI category column
df_data['BMI_Classification'] = df_data.apply(b, axis=1)

#TEST
df_data.head()
# Out:
#              name handedness  height  weight    avg   HR        BMI  \
# 0       Tom Brown          R      73     170  0.000    0  22.426346
# 1  Denny Lemaster          R      73     182  0.130    4  24.009383
# 2       Joe Nolan          L      71     175  0.263   27  24.404880
# 3     Denny Doyle          L      69     175  0.250   16  25.840160
# 4   Jose Cardenal          R      70     150  0.275  138  21.520408
#
#   BMI_Classification
# 0             normal
# 1             normal
# 2             normal
# 3         overweight
# 4             normal

# %% [markdown]
# ### Rename and Reorder Columns

# %%
#rename columns
df_data = df_data.rename(columns={'avg': 'BA', 'handedness': 'Batted', 'name': 'Name',
                                 'height': 'Height','weight': 'Weight'})

#reorder the columns
df_data = df_data[['Name', 'Batted', 'BA', 'HR', 'Height', 'Weight', 'BMI', 'BMI_Classification']]

# %%
#check for null data in BMI classification
sum(df_data.BMI_Classification.isnull())
# Out:
# 0

# %%
#TEST
df_data.head()
# Out:
#              Name Batted     BA   HR  Height  Weight        BMI  \
# 0       Tom Brown      R  0.000    0      73     170  22.426346
# 1  Denny Lemaster      R  0.130    4      73     182  24.009383
# 2       Joe Nolan      L  0.263   27      71     175  24.404880
# 3     Denny Doyle      L  0.250   16      69     175  25.840160
# 4   Jose Cardenal      R  0.275  138      70     150  21.520408
#
#   BMI_Classification
# 0             normal
# 1             normal
# 2             normal
# 3         overweight
# 4             normal

# %% [markdown]
# ### Drop Players without Batting Statistics

# %%
#drop players without batting stats
df_data = df_data.drop(df_data[(df_data.BA == 0) & (df_data.HR == 0)].index)

#Test check dataframe
df_data
# Out:
#                   Name Batted     BA   HR  Height  Weight        BMI  \
# 1       Denny Lemaster      R  0.130    4      73     182  24.009383
# 2            Joe Nolan      L  0.263   27      71     175  24.404880
# 3          Denny Doyle      L  0.250   16      69     175  25.840160
# 4        Jose Cardenal      R  0.275  138      70     150  21.520408
# 5            Mike Ryan      R  0.193   28      74     205  26.317568
# 6       Fritz Peterson      B  0.159    2      72     185  25.087770
# 7         Dick Bertell      R  0.250   10      72     200  27.121914
# 8           Rod Kanehl      R  0.241    6      73     180  23.745543
# 12        Juan Bonilla      R  0.256    7      69     170  25.101869
# 13      Frank Tepedino      L  0.241    6      71     185  25.799445
# 15           Rick Wise      R  0.195   15      73     180  23.745543
# 16       Darrell Evans      L  0.248  414      74     200  25.675676
# 17       Buck Martinez      R  0.225   58      70     190  27.259184
# 18     John Wockenfuss      R  0.262   86      72     190  25.765818
# 19        Tommy McCraw      L  0.246   75      72     183  24.816551
# 23            Lee Lacy      R  0.286   91      73     175  23.085945
# 24           Pete Rose      B  0.303  160      71     192  26.775640
# 25        Danny Walton      R  0.223   28      72     195  26.443866
# 26           Bobby Cox      R  0.225    9      71     180  25.102162
# 27        Brad Wellman      R  0.231    6      72     170  23.053627
# 28         Jeff Newman      R  0.224   63      74     215  27.601351
# 29      Pedro Gonzalez      R  0.244    8      72     176  23.867284
# 31     Tommie Reynolds      R  0.226   12      74     190  24.391892
# 32         Gene Clines      R  0.277    5      69     170  25.101869
# 33         Jim Hickman      R  0.252  159      75     192  23.995733
# 34     Jack Billingham      R  0.111    0      76     195  23.733553
# 35        Jerry Buchek      R  0.220   22      71     185  25.799445
# 36        Ivan DeJesus      R  0.254   21      71     175  24.404880
# 37          Gary Nolan      R  0.138    1      74     197  25.290541
# 39      Fred Whitfield      L  0.253  108      73     190  25.064740
# ...                ...    ...    ...  ...     ...     ...        ...
# 1114      Jesse Gonder      L  0.251   26      70     180  25.824490
# 1115   Gary Sutherland      R  0.243   24      72     185  25.087770
# 1116      Bob Coluccio      R  0.220   26      71     183  25.520532
# 1117        Dave Rader      L  0.257   30      71     165  23.010315
# 1118    Ron Gardenhire      R  0.232    4      72     175  23.731674
# 1119        Bill Sharp      L  0.255    9      70     178  25.537551
# 1120    Alan Bannister      R  0.270   19      71     170  23.707598
# 1121        Bob Watson      R  0.295  184      72     201  27.257523
# 1122     Ken Harrelson      R  0.239  131      74     190  24.391892
# 1123        Bobby Wine      R  0.215   30      73     187  24.668981
# 1125      John Kennedy      R  0.225   32      72     185  25.087770
# 1126        Chico Ruiz      B  0.240    2      72     169  22.918017
# 1128      Gail Hopkins      L  0.266   25      70     198  28.406939
# 1129       Doug Frobel      L  0.201   20      76     196  23.855263
# 1130     Luis Melendez      R  0.248    9      72     165  22.375579
# 1132      Bill Plummer      R  0.188   14      73     190  25.064740
# 1133      Buck Rodgers      B  0.232   31      74     190  24.391892
# 1134       Phil Niekro      R  0.169    7      73     180  23.745543
# 1136      Tom Poquette      L  0.268   10      70     175  25.107143
# 1138  Brian Asselstine      L  0.254   12      73     175  23.085945
# 1139       Rick Miller      L  0.269   28      72     175  23.731674
# 1140        Ed Charles      R  0.263   86      70     170  24.389796
# 1141        Luis Gomez      R  0.210    0      69     150  22.148708
# 1144     Floyd Rayford      R  0.244   38      70     190  27.259184
# 1146   Tony Conigliaro      R  0.264  166      75     185  23.120889
# 1148          Jim Barr      R  0.162    1      75     205  25.620444
# 1149        Jerry Remy      L  0.275    7      69     165  24.363579
# 1151       Frank Duffy      R  0.232   26      73     180  23.745543
# 1153      Tom O'Malley      L  0.256   13      72     180  24.409722
# 1154       Phil Garner      R  0.260  109      70     175  25.107143
#
#      BMI_Classification
# 1                normal
# 2                normal
# 3            overweight
# 4                normal
# 5            overweight
# 6            overweight
# 7            overweight
# 8                normal
# 12           overweight
# 13           overweight
# 15               normal
# 16           overweight
# 17           overweight
# 18           overweight
# 19               normal
# 23               normal
# 24           overweight
# 25           overweight
# 26           overweight
# 27               normal
# 28           overweight
# 29               normal
# 31               normal
# 32           overweight
# 33               normal
# 34               normal
# 35           overweight
# 36               normal
# 37           overweight
# 39           overweight
# ...                 ...
# 1114         overweight
# 1115         overweight
# 1116         overweight
# 1117             normal
# 1118             normal
# 1119         overweight
# 1120             normal
# 1121         overweight
# 1122             normal
# 1123             normal
# 1125         overweight
# 1126             normal
# 1128         overweight
# 1129             normal
# 1130             normal
# 1132         overweight
# 1133             normal
# 1134             normal
# 1136         overweight
# 1138             normal
# 1139             normal
# 1140             normal
# 1141             normal
# 1144         overweight
# 1146             normal
# 1148         overweight
# 1149             normal
# 1151             normal
# 1153             normal
# 1154         overweight
#
# [891 rows x 8 columns]

# %%
#Test view dataframe info
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 1154
# Data columns (total 8 columns):
# Name                  891 non-null object
# Batted                891 non-null object
# BA                    891 non-null float64
# HR                    891 non-null int64
# Height                891 non-null int64
# Weight                891 non-null int64
# BMI                   891 non-null float64
# BMI_Classification    891 non-null object
# dtypes: float64(2), int64(3), object(3)
# memory usage: 62.6+ KB

# %%
#save wrangled baseball data file for data story in tableau
df_data.to_csv('baseball_data_new.csv', encoding='utf-8', index=False)
